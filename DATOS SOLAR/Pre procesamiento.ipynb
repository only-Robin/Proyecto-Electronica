# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
f = os.getcwd()
f
# Out:
# 'C:\\Users\\USUARIO\\OneDrive\\Universidad\\Proyecto de Grado\\Repositorio\\Proyecto-Electronica\\DATOS SOLAR'

# %%
f = os.getcwd()

mes = input('Ingrese el mes: ')
año = input('Ingrese el año: ')
datos = pd.read_csv(f+ '\\'+ mes+' '+año+'.csv',encoding= 'UTF-8',error_bad_lines=False)
datos
# Out:
# Ingrese el mes: Diciembre
# Ingrese el año: 2020
#            Fecha   Hora Potencia [kW]  Insolacion [W/m2]  \
# 0      1/12/2020   0:00             x               0.98
# 1      1/12/2020   0:05             x               0.98
# 2      1/12/2020   0:10             x               0.98
# 3      1/12/2020   0:15             x               0.99
# 4      1/12/2020   0:20             x               0.99
# ...          ...    ...           ...                ...
# 8923  31/12/2020  23:35             x               0.96
# 8924  31/12/2020  23:40             x               0.97
# 8925  31/12/2020  23:45             x               0.97
# 8926  31/12/2020  23:50             x               0.96
# 8927  31/12/2020  23:55             x               0.96
#
#       Temperatura de modulos [C]  Temperatura Ambiente [C]  \
# 0                          14.17                 14.282958
# 1                          14.22                 14.281543
# 2                          14.27                 14.290481
# 3                          14.35                 14.287433
# 4                          14.44                 14.316995
# ...                          ...                       ...
# 8923                       12.34                 12.383408
# 8924                       12.53                 12.367861
# 8925                       12.54                 12.364678
# 8926                       12.42                 12.369157
# 8927                       12.40                 12.386796
#
#       Insolacion media [W/m2]
# 0                    0.983333
# 1                    0.982857
# 2                    0.982500
# 3                    0.982222
# 4                    0.982000
# ...                       ...
# 8923                 0.967000
# 8924                 0.966667
# 8925                 0.966250
# 8926                 0.965714
# 8927                 0.965000
#
# [8928 rows x 7 columns]

# %%
datos
# Out:
#            Fecha   Hora Potencia [kW]  Insolacion [W/m2]  \
# 0      1/12/2020   0:00             x               0.98
# 1      1/12/2020   0:05             x               0.98
# 2      1/12/2020   0:10             x               0.98
# 3      1/12/2020   0:15             x               0.99
# 4      1/12/2020   0:20             x               0.99
# ...          ...    ...           ...                ...
# 8923  31/12/2020  23:35             x               0.96
# 8924  31/12/2020  23:40             x               0.97
# 8925  31/12/2020  23:45             x               0.97
# 8926  31/12/2020  23:50             x               0.96
# 8927  31/12/2020  23:55             x               0.96
#
#       Temperatura de modulos [C]  Temperatura Ambiente [C]  \
# 0                          14.17                 14.282958
# 1                          14.22                 14.281543
# 2                          14.27                 14.290481
# 3                          14.35                 14.287433
# 4                          14.44                 14.316995
# ...                          ...                       ...
# 8923                       12.34                 12.383408
# 8924                       12.53                 12.367861
# 8925                       12.54                 12.364678
# 8926                       12.42                 12.369157
# 8927                       12.40                 12.386796
#
#       Insolacion media [W/m2]
# 0                    0.983333
# 1                    0.982857
# 2                    0.982500
# 3                    0.982222
# 4                    0.982000
# ...                       ...
# 8923                 0.967000
# 8924                 0.966667
# 8925                 0.966250
# 8926                 0.965714
# 8927                 0.965000
#
# [8928 rows x 7 columns]

# %%
list = datos['Hora'][0:72].tolist()
list2 = datos['Hora'][217:288].tolist()

list = list+list2

# %%
datosR = datos
#datos = datosR

for i in range(len(list)):
    datos = datos[datos['Hora']!= list[i]]

# %%
datos
# Out:
#            Fecha   Hora Potencia [kW]  Insolacion [W/m2]  \
# 72     1/12/2020   6:00          0.18              11.90
# 73     1/12/2020   6:05          0.47              19.73
# 74     1/12/2020   6:10          0.85              29.16
# 75     1/12/2020   6:15           1.5              43.71
# 76     1/12/2020   6:20          2.09              57.10
# ...          ...    ...           ...                ...
# 8852  31/12/2020  17:40          0.11               8.69
# 8853  31/12/2020  17:45           0.1               7.89
# 8854  31/12/2020  17:50          0.02               5.31
# 8855  31/12/2020  17:55             0               3.45
# 8856  31/12/2020  18:00             0               2.09
#
#       Temperatura de modulos [C]  Temperatura Ambiente [C]  \
# 72                         12.80                 12.487816
# 73                         12.76                 12.399875
# 74                         12.78                 12.309677
# 75                         13.11                 12.227736
# 76                         13.44                 12.232218
# ...                          ...                       ...
# 8852                       12.66                 12.491320
# 8853                       12.54                 12.450505
# 8854                       12.50                 12.425748
# 8855                       12.33                 12.404370
# 8856                       12.09                 12.398277
#
#       Insolacion media [W/m2]
# 72                  21.864545
# 73                  28.731818
# 74                  36.838182
# 75                  46.760000
# 76                  57.803636
# ...                       ...
# 8852                 9.208182
# 8853                 7.816364
# 8854                 6.237273
# 8855                 4.733636
# 8856                 3.798182
#
# [4495 rows x 7 columns]

# %%
try:
    print(datos[datos['Temperatura ambiente [C]']>23.5])
except: 
    print(datos[datos['Temperatura Ambiente [C]']>23.5])
# Out:
#            Fecha   Hora Potencia [kW]  Insolacion [W/m2]  \
# 154    1/12/2020  12:50         48.41            1127.24
# 155    1/12/2020  12:55         26.46             596.51
# 156    1/12/2020  13:00         25.94             543.99
# 157    1/12/2020  13:05         33.31             751.66
# 158    1/12/2020  13:10         10.79             216.54
# ...          ...    ...           ...                ...
# 8784  31/12/2020  12:00         20.78             453.85
# 8785  31/12/2020  12:05         11.11             235.41
# 8786  31/12/2020  12:10          6.61             130.17
# 8787  31/12/2020  12:15          4.91             114.88
# 8788  31/12/2020  12:20          5.92             148.48
#
#       Temperatura de modulos [C]  Temperatura Ambiente [C]  \
# 154                        46.51                 23.732345
# 155                        48.46                 24.020009
# 156                        44.94                 24.202273
# 157                        47.85                 24.338764
# 158                        40.56                 24.576739
# ...                          ...                       ...
# 8784                       40.99                 25.179950
# 8785                       36.63                 25.186334
# 8786                       31.92                 25.307511
# 8787                       28.85                 24.396266
# 8788                       26.21                 23.511498
#
#       Insolacion media [W/m2]
# 154                429.898182
# 155                431.305454
# 156                433.272727
# 157                436.640000
# 158                434.531818
# ...                       ...
# 8784               346.910909
# 8785               316.166364
# 8786               257.677273
# 8787               219.375454
# 8788               183.119091
#
# [448 rows x 7 columns]

# %%
try:
    for i in datos['Temperatura ambiente [C]']:   
        if i<23.5:
            m=i
        if i >23.5:
            datos.replace({'Temperatura ambiente [C]':i},m,inplace=True)
except:
    for i in datos['Temperatura Ambiente [C]']:   
        if i<23.5:
            m=i
        if i >23.5:
            datos.replace({'Temperatura Ambiente [C]':i},m,inplace=True)

# %%
try: 
    print(datos[datos['Temperatura ambiente [C]']>23.5])
except:
    print(datos[datos['Temperatura Ambiente [C]']>23.5])
# Out:
# Empty DataFrame
# Columns: [Fecha, Hora, Potencia [kW], Insolacion [W/m2], Temperatura de modulos [C], Temperatura Ambiente [C], Insolacion media [W/m2]]
# Index: []

# %%
try:
    plt.plot(datos['Temperatura ambiente [C]'][1:100])
except:
    plt.plot(datos['Temperatura Ambiente [C]'][1:100])

# %%
datos.to_csv(f+'\\Pre procesados\\'+mes+' '+año+'.csv')

# %%
import pvlib
