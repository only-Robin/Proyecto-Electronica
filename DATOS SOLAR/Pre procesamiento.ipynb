# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
f = os.getcwd()
f
# Out:
# 'C:\\Users\\USUARIO\\OneDrive\\Universidad\\Proyecto de Grado\\Repositorio\\Proyecto-Electronica\\DATOS SOLAR'

# %%
f = os.getcwd()
mes = input('Ingrese el mes: ')
año = input('Ingrese el año: ')

datos = pd.read_csv(f+ '\\'+ mes+' '+año+'.csv',encoding= 'UTF-8',error_bad_lines=False)
datos
# Out:
# Ingrese el mes: Octubre
# Ingrese el año: 2019
#            Fecha   Hora Potencia [kW]  Insolacion [W/m2]  \
# 0      1/10/2019   0:00             x               1.04
# 1      1/10/2019   0:05             x               1.04
# 2      1/10/2019   0:10             x               1.04
# 3      1/10/2019   0:15             x               1.04
# 4      1/10/2019   0:20             x               1.04
# ...          ...    ...           ...                ...
# 8923  31/10/2019  23:35             x               1.01
# 8924  31/10/2019  23:40             x               1.02
# 8925  31/10/2019  23:45             x               1.01
# 8926  31/10/2019  23:50             x               1.02
# 8927  31/10/2019  23:55             x               1.01
#
#       Temperatura de modulos [C]  Temperatura ambiente [C]
# 0                          10.27                 10.344733
# 1                          10.06                 10.387114
# 2                          10.25                 10.412650
# 3                          10.46                 10.413622
# 4                          10.64                 10.405428
# ...                          ...                       ...
# 8923                       10.45                 10.546032
# 8924                       10.44                 10.500931
# 8925                       10.42                 10.460803
# 8926                       10.48                 10.437782
# 8927                       10.52                 10.428754
#
# [8928 rows x 6 columns]
