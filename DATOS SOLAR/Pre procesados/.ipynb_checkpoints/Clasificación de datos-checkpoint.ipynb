# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import glob

# %%
mes = input('Ingrese el mes: ')
año = input('Ingrese el año: ')
mesActual = pd.read_csv(mes+' '+ año +'.csv')
mesActual.drop('Unnamed: 0',axis=1,inplace = True)
mesActual = mesActual[mesActual['Hora']!='18:00']
# Out:
# Ingrese el mes: Mayo
# Ingrese el año: 2020

# %%
mesActual
# Out:
#            Fecha   Hora  Potencia [kW]  Insolacion [W/m2]  \
# 0      1/05/2020   6:00           0.00               2.51
# 1      1/05/2020   6:05           0.00               3.58
# 2      1/05/2020   6:10           0.01               4.80
# 3      1/05/2020   6:15           0.06               6.13
# 4      1/05/2020   6:20           0.11               7.46
# ...          ...    ...            ...                ...
# 4459  31/05/2020  17:35           0.06               5.98
# 4460  31/05/2020  17:40           0.04               5.36
# 4461  31/05/2020  17:45           0.02               4.83
# 4462  31/05/2020  17:50           0.00               4.44
# 4463  31/05/2020  17:55           0.00               4.28
#
#       Temperatura de modulos [C]  Temperatura ambiente [C]  \
# 0                          11.78                 11.813286
# 1                          11.89                 11.842684
# 2                          11.83                 11.862109
# 3                          12.01                 11.869368
# 4                          12.10                 11.877645
# ...                          ...                       ...
# 4459                       14.05                 13.899084
# 4460                       13.62                 13.868143
# 4461                       13.58                 13.806243
# 4462                       13.73                 13.737793
# 4463                       13.80                 13.696145
#
#       Insolacion media [W/m2]  Temp Ambiente [C]
# 0                    3.649091          11.813286
# 1                    4.662727          11.842684
# 2                    5.774545          11.862109
# 3                    6.998182          11.869368
# 4                    8.250909          11.877645
# ...                       ...                ...
# 4459                11.339091          13.899084
# 4460                 9.588182          13.868143
# 4461                 7.475455          13.806243
# 4462                 5.237273          13.737793
# 4463                 3.941818          13.696145
#
# [4464 rows x 8 columns]

# %% [markdown]
# ## Creación del dataframe con todos los datos por hora

# %%
#Función para generar un dataframe con los datos de Energia en kWh 
#y de irradiación en Wh/m2 por cada hora del día

def nuevoFrame(mesActual):
    i = 0
    j = 0
    energia = []
    irradiacion = []
    fechas = []
    horas = []
    try:
        while i<len(mesActual):
            fechas.append(mesActual['Fecha'][i])
            horas.append(mesActual['Hora'][i])
            energia.append(mesActual['Potencia [kW]'][i:i+12].sum()/12)
            irradiacion.append(mesActual['Insolacion [W/m2]'][i:i+12].sum()/12)
            i+=12
        datos = pd.DataFrame({'Fecha':fechas,'Hora':horas,'Energia [kWh]':energia,'Irradiacion [Wh/m2]':irradiacion})
        return datos
    except:
        pass

# %%
# Se leen los diferentes archivos csv que existen en la carpeta actual
archivos = glob.glob('*.csv')
archivos
# Out:
# ['Abril 2020.csv',
#  'Agosto 2020.csv',
#  'DataFinalBeta.csv',
#  'Diciembre 2019.csv',
#  'Diciembre 2020.csv',
#  'Energia e irradiacion por hora.csv',
#  'Enero 2020.csv',
#  'Estadisticas por hora.csv',
#  'Febrero 2020.csv',
#  'Julio 2020.csv',
#  'Junio 2020.csv',
#  'Marzo 2020.csv',
#  'Mayo 2020.csv',
#  'Noviembre 2019.csv',
#  'Noviembre 2020.csv',
#  'Octubre 2019.csv',
#  'Octubre 2020.csv',
#  'Septiembre 2020.csv',
#  'Todo por hora.csv']

# %% [markdown]
# ### Nuevo dataframe:

# %%
# Se leen los diferentes archivos y se ejecuta sobre cada uno la función 'nuevoFrame'
# Luego se concatenan cada uno de estos dataFrames en uno solo
inicio = 0

for name in archivos:
    mesActual = pd.read_csv(name)      #Lectura
    mesActual = nuevoFrame(mesActual)  #Ejecución
    
    if inicio == 0:
        dataFrame = mesActual
    else:
        dataFrame = pd.concat([dataFrame,mesActual])
    inicio+=1

# %%
inicio
# Out:
# 19

# %%
dataFrame.to_csv('Todo por hora.csv')

# %%
dataFrame['Energia [kWh]'].plot()
plt.show()
dataFrame['Irradiacion [Wh/m2]'].plot()

# %%
horas = dataFrame['Hora'].unique()
horas
# Out:
# array(['6:00', '7:00', '8:00', '9:00', '10:00', '11:00', '12:00', '13:00',
#        '14:00', '15:00', '16:00', '17:00'], dtype=object)

# %%
irr_prom = []
ene_prom = []

irr_std = []
ene_std = []

for h in horas:
    df = dataFrame[dataFrame['Hora']==h]
    
    energy = df['Energia [kWh]'].mean()
    irradiance  =df['Irradiacion [Wh/m2]'].mean()
    
    energy_std = df['Energia [kWh]'].std()
    irradiance_std  =df['Irradiacion [Wh/m2]'].std()
    
    ene_prom.append(energy)
    irr_prom.append(irradiance)
    
    ene_std.append(energy_std)
    irr_std.append(irradiance_std)

# %%
porHora = pd.DataFrame({'Hora':horas,'Energia Prom [kWh]':ene_prom,'Irradiacion Prom [Wh/m2]':irr_prom,
                        'Energia desv [kWh]': ene_std,'Irradiacion desv [Wh/m2]':irr_std})
porHora.to_csv('Estadisticas por hora.csv')

# %%
porHora
# Out:
#      Hora  Energia Prom [kWh]  Irradiacion Prom [Wh/m2]  Energia desv [kWh]  \
# 0    6:00            1.669605                 36.732636            1.132852
# 1    7:00            9.283936                189.370182            4.759372
# 2    8:00           19.101243                354.244176            9.229886
# 3    9:00           25.971177                463.021567           11.903278
# 4   10:00           30.415977                530.439156           14.084939
# 5   11:00           31.178832                535.630262           15.108984
# 6   12:00           28.835844                480.730073           15.478485
# 7   13:00           24.735045                350.265122           14.606989
# 8   14:00           19.001918                238.343834           11.545151
# 9   15:00           12.224898                149.608231            8.140235
# 10  16:00            6.130351                 80.233135            4.240660
# 11  17:00            1.466508                 24.785133            1.246676
#
#     Irradiacion desv [Wh/m2]
# 0                  22.037113
# 1                 109.302048
# 2                 176.658672
# 3                 215.963951
# 4                 247.390029
# 5                 263.046497
# 6                 259.766559
# 7                 195.562491
# 8                 150.413175
# 9                  97.757426
# 10                 47.309124
# 11                 16.417209

# %%
hora = input('Hora: \nEntre 6:00 y 17:00\n')
plt.scatter(range(len(dataFrame[dataFrame['Hora']==hora])),dataFrame[dataFrame['Hora']==hora]['Irradiacion [Wh/m2]'])
# Out:
# Hora:
# Entre 6:00 y 17:00
# 8:00

# %%
promedios = pd.read_csv('Estadisticas por hora.csv')
promedios.drop('Unnamed: 0',axis = 1,inplace = True)
promedios
# Out:
#      Hora  Energia Prom [kWh]  Irradiacion Prom [Wh/m2]  Energia desv [kWh]  \
# 0    6:00            1.669605                 36.732636            1.132852
# 1    7:00            9.283936                189.370182            4.759372
# 2    8:00           19.101243                354.244176            9.229886
# 3    9:00           25.971177                463.021567           11.903278
# 4   10:00           30.415977                530.439156           14.084939
# 5   11:00           31.178832                535.630262           15.108984
# 6   12:00           28.835844                480.730073           15.478485
# 7   13:00           24.735045                350.265122           14.606989
# 8   14:00           19.001918                238.343834           11.545151
# 9   15:00           12.224898                149.608231            8.140235
# 10  16:00            6.130351                 80.233135            4.240660
# 11  17:00            1.466508                 24.785133            1.246676
#
#     Irradiacion desv [Wh/m2]
# 0                  22.037113
# 1                 109.302048
# 2                 176.658672
# 3                 215.963951
# 4                 247.390029
# 5                 263.046497
# 6                 259.766559
# 7                 195.562491
# 8                 150.413175
# 9                  97.757426
# 10                 47.309124
# 11                 16.417209

# %%
rango1 = []
rango2 = []
horas = promedios['Hora']
for i in range(len(promedios)):
    lim1 = promedios['Irradiacion Prom [Wh/m2]'][i] - promedios['Irradiacion desv [Wh/m2]'][i]/2
    lim2 = promedios['Irradiacion Prom [Wh/m2]'][i] + promedios['Irradiacion desv [Wh/m2]'][i]/2
    
    rango1.append(lim1)
    rango2.append(lim2)
rangos = pd.DataFrame({'Hora':horas,'Limite Inf':rango1,'Limite Sup':rango2})
rangos.set_index('Hora',inplace = True)
rangos
# Out:
#        Limite Inf  Limite Sup
# Hora
# 6:00    25.714080   47.751193
# 7:00   134.719158  244.021206
# 8:00   265.914840  442.573512
# 9:00   355.039591  571.003542
# 10:00  406.744141  654.134170
# 11:00  404.107013  667.153511
# 12:00  350.846793  610.613352
# 13:00  252.483876  448.046368
# 14:00  163.137246  313.550421
# 15:00  100.729519  198.486944
# 16:00   56.578573  103.887697
# 17:00   16.576528   32.993737

# %%
todoporHora = pd.read_csv('Todo por hora.csv')
todoporHora.drop('Unnamed: 0',axis = 1,inplace = True)
todoporHora
# Out:
#            Fecha   Hora  Energia [kWh]  Irradiacion [Wh/m2]
# 0      1/04/2020   6:00       1.005833            22.875000
# 1      1/04/2020   7:00       6.593333           115.340833
# 2      1/04/2020   8:00      15.385833           269.870000
# 3      1/04/2020   9:00       6.713333           118.296667
# 4      1/04/2020  10:00       3.472500            59.250000
# ...          ...    ...            ...                  ...
# 5491  30/09/2020  13:00      39.585000           741.970833
# 5492  30/09/2020  14:00      24.003333           398.950000
# 5493  30/09/2020  15:00      10.800833           170.588333
# 5494  30/09/2020  16:00       4.070000            72.150833
# 5495  30/09/2020  17:00       0.966667            23.785000
#
# [5496 rows x 4 columns]

# %% [markdown]
# # Clasificación

# %%
m = len(todoporHora)

soleados = [0]*m
lluviosos = [0]*m
nubados = [0]*m

horas = todoporHora['Hora'].unique()
fechas = todoporHora.Fecha

for h in horas:
    inf = rangos['Limite Inf'][h]
    sup = rangos['Limite Sup'][h]
    for i in range(len(todoporHora)):
        irr_actual =todoporHora['Irradiacion [Wh/m2]'][i]
        
        if todoporHora['Hora'][i] == h:
            if  irr_actual < inf:
                lluviosos[i] = 1
                
            elif inf < irr_actual < sup:
                nubados[i] = 1
            
            else:
                soleados[i] = 1

clima = pd.DataFrame({'Fecha':fechas,'Hora':todoporHora['Hora'],'Lluvioso':lluviosos, 'Nublado':nubados,'Soleado':soleados})

# %%
sum(lluviosos)*12
# Out:
# 24696

# %%
clima
# Out:
#            Fecha   Hora  Lluvioso  Nublado  Soleado
# 0      1/04/2020   6:00         1        0        0
# 1      1/04/2020   7:00         1        0        0
# 2      1/04/2020   8:00         0        1        0
# 3      1/04/2020   9:00         1        0        0
# 4      1/04/2020  10:00         1        0        0
# ...          ...    ...       ...      ...      ...
# 5491  30/09/2020  13:00         0        0        1
# 5492  30/09/2020  14:00         0        0        1
# 5493  30/09/2020  15:00         0        1        0
# 5494  30/09/2020  16:00         0        1        0
# 5495  30/09/2020  17:00         0        1        0
#
# [5496 rows x 5 columns]

# %%
counts = [sum(nubados)/5496, sum(lluviosos)/5496,sum(soleados)/5496]
estado = ['Nublado','Lluvioso','Soleado']

colores = ["#EE6055","#60D394","#AAF683"]

plt.figure(figsize=(10,6))
plt.pie(counts,labels = estado,autopct="%0.1f %%",colors = colores)
plt.title('Porcentaje de horas lluviosas, soleadas y nubladas')
plt.axis('equal')

# Muestra de 5496 datos
# Out:
# (-1.118892723532241, 1.1008996535015352, -1.11140673916611, 1.1135056364927596)

# %%
horas = clima.Hora.unique()
n = len(horas)
lluvia = [0]*n
sol = [0]*n
nube = [0]*n
for i in range(len(horas)):
    lluvia[i] = clima[clima['Hora']==horas[i]]['Lluvioso'].sum()
    sol[i] = clima[clima['Hora']==horas[i]]['Soleado'].sum()
    nube[i] = clima[clima['Hora']==horas[i]]['Nublado'].sum()
climaHora = pd.DataFrame({'Hora':horas,'Lluvioso':lluvia,'Soleado':sol,'Nublado':nube})
climaHora.set_index('Hora',inplace = True)

# %%
colores = ["#DE6055","#60D394","#AAF683"]
climaHora.plot.bar(figsize = (12,8),grid = True,color = colores)
plt.title('Frecuencia de tipo de clima por hora')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# # DataFrames Finales

# %%
#Función para generar un dataframe con los datos de Energia en kWh 
#y de irradiación en Wh/m2 por cada uno de los datos 

def nuevoFrame(mesActual):
    i = 0
    j = 0
    energia = []
    irradiacion = []
    fechas = []
    horas = []
    try:
        while i<len(mesActual):
            fechas.append(mesActual['Fecha'][i])
            horas.append(mesActual['Hora'][i])
            energia.append(mesActual['Potencia [kW]'][i:i+12].sum()/12)
            irradiacion.append(mesActual['Insolacion [W/m2]'][i:i+12].sum()/12)
            i+=12
        datos = pd.DataFrame({'Fecha':fechas,'Hora':horas,'Energia [kWh]':energia,'Irradiacion [Wh/m2]':irradiacion})
        return datos
    except:
        pass

# %%
#Función para generar un dataframe con los datos de Energia en kWh 
#y de irradiación en Wh/m2 por cada hora del día

def nuevoFrame2(mesActual):
    try:
        fechas = mesActual['Fecha']
        horas = mesActual['Hora']
        energia = mesActual['Potencia [kW]']
        irradiacion = mesActual['Insolacion [W/m2]']
        temperatura = mesActual['Temperatura de modulos [C]']
        datos = pd.DataFrame({'Fecha':fechas,'Hora':horas,'Potencia [kW]':energia,'Irradiacion [W/m2]':irradiacion,
                              'Temperatura de modulos[C]':temperatura})
        return datos
    except:
        pass

# %%
archivos = glob.glob('*.csv')
archivos
# Out:
# ['Abril 2020.csv',
#  'Agosto 2020.csv',
#  'DataFinalBeta.csv',
#  'Diciembre 2019.csv',
#  'Diciembre 2020.csv',
#  'Energia e irradiacion por hora.csv',
#  'Enero 2020.csv',
#  'Estadisticas por hora.csv',
#  'Febrero 2020.csv',
#  'Julio 2020.csv',
#  'Junio 2020.csv',
#  'Marzo 2020.csv',
#  'Mayo 2020.csv',
#  'Noviembre 2019.csv',
#  'Noviembre 2020.csv',
#  'Octubre 2019.csv',
#  'Octubre 2020.csv',
#  'Septiembre 2020.csv',
#  'Todo por hora.csv']

# %%
start = 0
for arch in archivos:
    df = pd.read_csv(arch)
    df = nuevoFrame2(df)
    if start == 0:
        dataFinal= df
    else:
        dataFinal= pd.concat([dataFinal,df])
    start+=1
dataFinal.to_csv('DataFinalBeta.csv')

# %%
dataFinal = pd.read_csv('DataFinalBeta.csv')
dataFinal.drop('Unnamed: 0',axis = 1 ,inplace = True)
dataFinal.head(15)
# Out:
#         Fecha  Hora  Potencia [kW]  Irradiacion [W/m2]  \
# 0   1/04/2020  6:00           0.00                2.02
# 1   1/04/2020  6:05           0.00                3.20
# 2   1/04/2020  6:10           0.01                4.51
# 3   1/04/2020  6:15           0.11                6.98
# 4   1/04/2020  6:20           0.24               10.52
# 5   1/04/2020  6:25           0.46               14.78
# 6   1/04/2020  6:30           0.79               20.85
# 7   1/04/2020  6:35           1.25               29.65
# 8   1/04/2020  6:40           1.90               40.85
# 9   1/04/2020  6:45           2.35               46.22
# 10  1/04/2020  6:50           2.51               47.47
# 11  1/04/2020  6:55           2.45               47.45
# 12  1/04/2020  7:00           2.29               45.58
# 13  1/04/2020  7:05           2.78               53.34
# 14  1/04/2020  7:10           4.18               75.21
#
#     Temperatura de modulos[C]
# 0                       12.17
# 1                       12.33
# 2                       12.39
# 3                       12.04
# 4                       11.79
# 5                       11.90
# 6                       11.74
# 7                       11.61
# 8                       11.92
# 9                       12.72
# 10                      13.27
# 11                      13.29
# 12                      13.31
# 13                      13.45
# 14                      14.06

# %%
clima
# Out:
#            Fecha   Hora  Lluvioso  Nublado  Soleado
# 0      1/04/2020   6:00         1        0        0
# 1      1/04/2020   7:00         1        0        0
# 2      1/04/2020   8:00         0        1        0
# 3      1/04/2020   9:00         1        0        0
# 4      1/04/2020  10:00         1        0        0
# ...          ...    ...       ...      ...      ...
# 5491  30/09/2020  13:00         0        0        1
# 5492  30/09/2020  14:00         0        0        1
# 5493  30/09/2020  15:00         0        1        0
# 5494  30/09/2020  16:00         0        1        0
# 5495  30/09/2020  17:00         0        1        0
#
# [5496 rows x 5 columns]

# %%
n = len(clima)
soleado = []
nublado  = []
lluvioso = []

for i in range(n):
    soleado+=[clima['Soleado'][i]]*12
    lluvioso+=[clima['Lluvioso'][i]]*12
    nublado+=[clima['Nublado'][i]]*12

dataFinal['Lluvioso'] = lluvioso
dataFinal['Nublado'] = nublado
dataFinal['Soleado'] = soleado

# %%
dataFinal.Lluvioso.sum()
# Out:
# 24696

# %%
dataFinal[80:140]
# Out:
#          Fecha   Hora  Potencia [kW]  Irradiacion [W/m2]  \
# 80   1/04/2020  12:40          15.66              239.34
# 81   1/04/2020  12:45          15.07              237.19
# 82   1/04/2020  12:50          16.73              265.76
# 83   1/04/2020  12:55          14.53              230.73
# 84   1/04/2020  13:00          15.42              246.47
# 85   1/04/2020  13:05          16.91              270.41
# 86   1/04/2020  13:10          16.84              272.56
# 87   1/04/2020  13:15          13.30              219.59
# 88   1/04/2020  13:20           6.78              116.71
# 89   1/04/2020  13:25           5.51               92.95
# 90   1/04/2020  13:30           4.82               88.04
# 91   1/04/2020  13:35           4.82               90.12
# 92   1/04/2020  13:40           6.01              105.19
# 93   1/04/2020  13:45           7.46              125.68
# 94   1/04/2020  13:50           7.08              117.79
# 95   1/04/2020  13:55           5.14               84.71
# 96   1/04/2020  14:00           4.49               70.64
# 97   1/04/2020  14:05           2.69               47.61
# 98   1/04/2020  14:10           4.02               66.16
# 99   1/04/2020  14:15           5.77               90.83
# 100  1/04/2020  14:20           6.44              101.40
# 101  1/04/2020  14:25           4.36               74.12
# 102  1/04/2020  14:30           4.63               81.20
# 103  1/04/2020  14:35           7.08              120.10
# 104  1/04/2020  14:40           6.17              104.21
# 105  1/04/2020  14:45           7.01              119.77
# 106  1/04/2020  14:50           8.27              137.84
# 107  1/04/2020  14:55           7.73              127.57
# 108  1/04/2020  15:00           8.11              133.39
# 109  1/04/2020  15:05          10.63              176.38
# 110  1/04/2020  15:10          13.46              220.56
# 111  1/04/2020  15:15          12.90              209.62
# 112  1/04/2020  15:20           9.66              151.89
# 113  1/04/2020  15:25           8.63              133.89
# 114  1/04/2020  15:30           9.70              156.86
# 115  1/04/2020  15:35          10.38              163.27
# 116  1/04/2020  15:40          11.15              159.83
# 117  1/04/2020  15:45          11.59              161.42
# 118  1/04/2020  15:50          10.58              152.31
# 119  1/04/2020  15:55          10.48              148.69
# 120  1/04/2020  16:00           9.91              139.26
# 121  1/04/2020  16:05           8.59              121.92
# 122  1/04/2020  16:10           7.97              117.50
# 123  1/04/2020  16:15           8.77              134.32
# 124  1/04/2020  16:20           9.59              143.34
# 125  1/04/2020  16:25           7.19              112.78
# 126  1/04/2020  16:30           6.35              103.46
# 127  1/04/2020  16:35           7.21              115.75
# 128  1/04/2020  16:40           7.49              116.51
# 129  1/04/2020  16:45           7.24              109.65
# 130  1/04/2020  16:50           6.47              101.01
# 131  1/04/2020  16:55           5.33               83.01
# 132  1/04/2020  17:00           4.00               61.94
# 133  1/04/2020  17:05           2.52               43.06
# 134  1/04/2020  17:10           2.29               38.78
# 135  1/04/2020  17:15           2.33               40.91
# 136  1/04/2020  17:20           2.20               39.39
# 137  1/04/2020  17:25           1.96               36.05
# 138  1/04/2020  17:30           1.64               31.44
# 139  1/04/2020  17:35           1.21               25.31
#
#      Temperatura de modulos[C]  Lluvioso  Nublado  Soleado
# 80                       22.51         1        0        0
# 81                       22.77         1        0        0
# 82                       23.13         1        0        0
# 83                       23.73         1        0        0
# 84                       23.35         1        0        0
# 85                       23.97         1        0        0
# 86                       24.71         1        0        0
# 87                       25.13         1        0        0
# 88                       23.42         1        0        0
# 89                       21.83         1        0        0
# 90                       20.83         1        0        0
# 91                       19.99         1        0        0
# 92                       18.67         1        0        0
# 93                       17.39         1        0        0
# 94                       18.28         1        0        0
# 95                       18.36         1        0        0
# 96                       18.62         1        0        0
# 97                       18.23         1        0        0
# 98                       18.10         1        0        0
# 99                       18.68         1        0        0
# 100                      19.29         1        0        0
# 101                      18.87         1        0        0
# 102                      18.29         1        0        0
# 103                      18.81         1        0        0
# 104                      19.63         1        0        0
# 105                      19.95         1        0        0
# 106                      20.32         1        0        0
# 107                      19.61         1        0        0
# 108                      17.51         0        1        0
# 109                      18.61         0        1        0
# 110                      21.03         0        1        0
# 111                      23.03         0        1        0
# 112                      23.33         0        1        0
# 113                      22.53         0        1        0
# 114                      22.66         0        1        0
# 115                      23.04         0        1        0
# 116                      23.39         0        1        0
# 117                      23.83         0        1        0
# 118                      23.76         0        1        0
# 119                      23.66         0        1        0
# 120                      22.99         0        0        1
# 121                      22.44         0        0        1
# 122                      21.93         0        0        1
# 123                      21.73         0        0        1
# 124                      22.05         0        0        1
# 125                      22.28         0        0        1
# 126                      22.15         0        0        1
# 127                      22.17         0        0        1
# 128                      22.04         0        0        1
# 129                      21.73         0        0        1
# 130                      21.17         0        0        1
# 131                      20.66         0        0        1
# 132                      19.66         0        1        0
# 133                      18.94         0        1        0
# 134                      18.50         0        1        0
# 135                      17.77         0        1        0
# 136                      17.09         0        1        0
# 137                      16.65         0        1        0
# 138                      16.61         0        1        0
# 139                      16.55         0        1        0

# %%
clima.head(12)
# Out:
#         Fecha   Hora  Lluvioso  Nublado  Soleado
# 0   1/04/2020   6:00         1        0        0
# 1   1/04/2020   7:00         1        0        0
# 2   1/04/2020   8:00         0        1        0
# 3   1/04/2020   9:00         1        0        0
# 4   1/04/2020  10:00         1        0        0
# 5   1/04/2020  11:00         1        0        0
# 6   1/04/2020  12:00         1        0        0
# 7   1/04/2020  13:00         1        0        0
# 8   1/04/2020  14:00         1        0        0
# 9   1/04/2020  15:00         0        1        0
# 10  1/04/2020  16:00         0        0        1
# 11  1/04/2020  17:00         0        1        0

# %% [markdown]
# ##  Modelo SARIMAX por Hora

# %% [markdown]
# ### SARIMAX - Seasonal AutoRegressive (p) Integrated(d) Moving Average (q) Exogenous

# %%
todoporHora['Lluvioso'] = clima.Lluvioso
todoporHora['Nublado'] = clima.Nublado
todoporHora['Soleado'] = clima.Soleado
todoporHora1 = todoporHora
todoporHora
# Out:
#            Fecha   Hora  Energia [kWh]  Irradiacion [Wh/m2]  Lluvioso  \
# 0      1/04/2020   6:00       1.005833            22.875000         1
# 1      1/04/2020   7:00       6.593333           115.340833         1
# 2      1/04/2020   8:00      15.385833           269.870000         0
# 3      1/04/2020   9:00       6.713333           118.296667         1
# 4      1/04/2020  10:00       3.472500            59.250000         1
# ...          ...    ...            ...                  ...       ...
# 5491  30/09/2020  13:00      39.585000           741.970833         0
# 5492  30/09/2020  14:00      24.003333           398.950000         0
# 5493  30/09/2020  15:00      10.800833           170.588333         0
# 5494  30/09/2020  16:00       4.070000            72.150833         0
# 5495  30/09/2020  17:00       0.966667            23.785000         0
#
#       Nublado  Soleado
# 0           0        0
# 1           0        0
# 2           1        0
# 3           0        0
# 4           0        0
# ...       ...      ...
# 5491        0        1
# 5492        0        1
# 5493        1        0
# 5494        1        0
# 5495        1        0
#
# [5496 rows x 7 columns]

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
from statsmodels.tsa.stattools import acf,pacf

# %%
# plot_acf para identificar el parámetro q
# SARIMAX (p,q,d)(P,Q,D,T)
plot_acf(todoporHora['Energia [kWh]'],lags = np.arange(100))

# %%
plot_pacf(todoporHora['Energia [kWh]'],lags = np.arange(100))

# %%
promedio = dataFinal['Potencia [kW]'].mean()
proms = [promedio]*len(dataFinal)
dataFinal['Ajuste'] = np.log10(dataFinal['Potencia [kW]'])-proms
# Out:
# C:\Users\USUARIO\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
dataFinal
# Out:
#             Fecha   Hora  Potencia [kW]  Irradiacion [W/m2]  \
# 0       1/04/2020   6:00           0.00                2.02
# 1       1/04/2020   6:05           0.00                3.20
# 2       1/04/2020   6:10           0.01                4.51
# 3       1/04/2020   6:15           0.11                6.98
# 4       1/04/2020   6:20           0.24               10.52
# ...           ...    ...            ...                 ...
# 65947  30/09/2020  17:35           0.42               13.87
# 65948  30/09/2020  17:40           0.17                8.58
# 65949  30/09/2020  17:45           0.00                3.21
# 65950  30/09/2020  17:50           0.00                1.75
# 65951  30/09/2020  17:55           0.00                1.07
#
#        Temperatura de modulos[C]  Lluvioso  Nublado  Soleado     Ajuste
# 0                          12.17         1        0        0       -inf
# 1                          12.33         1        0        0       -inf
# 2                          12.39         1        0        0 -19.501278
# 3                          12.04         1        0        0 -18.459885
# 4                          11.79         1        0        0 -18.121067
# ...                          ...       ...      ...      ...        ...
# 65947                      15.79         0        1        0 -17.878029
# 65948                      15.75         0        1        0 -18.270829
# 65949                      15.58         0        1        0       -inf
# 65950                      15.54         0        1        0       -inf
# 65951                      14.91         0        1        0       -inf
#
# [65952 rows x 9 columns]

# %%
plot_acf(dataFinal['Potencia [kW]'],lags = np.arange(300))

# %%
plot_pacf(dataFinal['Potencia [kW]'], lags = np.arange(300))

# %% [markdown]
# ## Conversión a estacionario

# %%
dataFinal_m = dataFinal[0:4320]
dataFinal_m
# Out:
#            Fecha   Hora  Potencia [kW]  Irradiacion [W/m2]  \
# 0      1/04/2020   6:00           0.00                2.02
# 1      1/04/2020   6:05           0.00                3.20
# 2      1/04/2020   6:10           0.01                4.51
# 3      1/04/2020   6:15           0.11                6.98
# 4      1/04/2020   6:20           0.24               10.52
# ...          ...    ...            ...                 ...
# 4315  30/04/2020  17:35           0.48               13.52
# 4316  30/04/2020  17:40           0.32               10.56
# 4317  30/04/2020  17:45           0.17                8.05
# 4318  30/04/2020  17:50           0.06                5.26
# 4319  30/04/2020  17:55           0.00                3.65
#
#       Temperatura de modulos[C]  Lluvioso  Nublado  Soleado     Ajuste
# 0                         12.17         1        0        0       -inf
# 1                         12.33         1        0        0       -inf
# 2                         12.39         1        0        0 -19.501278
# 3                         12.04         1        0        0 -18.459885
# 4                         11.79         1        0        0 -18.121067
# ...                         ...       ...      ...      ...        ...
# 4315                      17.89         1        0        0 -17.820037
# 4316                      17.81         1        0        0 -17.996128
# 4317                      17.82         1        0        0 -18.270829
# 4318                      17.73         1        0        0 -18.723127
# 4319                      17.53         1        0        0       -inf
#
# [4320 rows x 9 columns]

# %%
ajuste = []
for i in range(len(dataFinal_m)):
    p_actual = dataFinal_m['Potencia [kW]'][i]
    if p_actual ==0.0:
        ajuste.append(np.log10(0.01))
    else:
        ajuste.append(np.log10(p_actual))
dataFinal_m['Ajuste'] = ajuste
dataFinal_m
# Out:
# C:\Users\USUARIO\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            Fecha   Hora  Potencia [kW]  Irradiacion [W/m2]  \
# 0      1/04/2020   6:00           0.00                2.02
# 1      1/04/2020   6:05           0.00                3.20
# 2      1/04/2020   6:10           0.01                4.51
# 3      1/04/2020   6:15           0.11                6.98
# 4      1/04/2020   6:20           0.24               10.52
# ...          ...    ...            ...                 ...
# 4315  30/04/2020  17:35           0.48               13.52
# 4316  30/04/2020  17:40           0.32               10.56
# 4317  30/04/2020  17:45           0.17                8.05
# 4318  30/04/2020  17:50           0.06                5.26
# 4319  30/04/2020  17:55           0.00                3.65
#
#       Temperatura de modulos[C]  Lluvioso  Nublado  Soleado    Ajuste
# 0                         12.17         1        0        0 -2.000000
# 1                         12.33         1        0        0 -2.000000
# 2                         12.39         1        0        0 -2.000000
# 3                         12.04         1        0        0 -0.958607
# 4                         11.79         1        0        0 -0.619789
# ...                         ...       ...      ...      ...       ...
# 4315                      17.89         1        0        0 -0.318759
# 4316                      17.81         1        0        0 -0.494850
# 4317                      17.82         1        0        0 -0.769551
# 4318                      17.73         1        0        0 -1.221849
# 4319                      17.53         1        0        0 -2.000000
#
# [4320 rows x 9 columns]

# %%
prim_diff = dataF
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-9a593ad3ca83> in <module>
# ----> 1 prim_diff = dataF
#
# NameError: name 'dataF' is not defined

# %%
plt.plot(prim_Diff)
plt.title('Primera diferencia')
plt.figure()
plt.plot(diff_144)
plt.title('Diferencia Estacional')

# %%
plot_acf(np.array(prim_Diff[1:]))

# %%
plot_acf(diff_144[145:])
